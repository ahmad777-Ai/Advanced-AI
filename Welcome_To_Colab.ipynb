# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmad777-Ai/Advanced-AI/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    "name" :['alice' , 'bob' , 'charlie' , 'david'],
    "age" : [25 , 30 , 17 , 28],
    "city" : ['new york' , 'san francisco' , 'chicago' , 'los angeles'],
    'salary': [500 , 600 , 450, 700]
}


df= pd.DataFrame(data)
df
# Out:
#       name  age           city  salary
# 0    alice   25       new york     500
# 1      bob   30  san francisco     600
# 2  charlie   17        chicago     450
# 3    david   28    los angeles     700

# %%
df[['name' , 'salary']]
# Out:
#       name  salary
# 0    alice     500
# 1      bob     600
# 2  charlie     450
# 3    david     700

# %%
df.T
# Out:
#                0              1        2            3
# name       alice            bob  charlie        david
# age           25             30       17           28
# city    new york  san francisco  chicago  los angeles
# salary       500            600      450          700

# %%
df.iloc[1]
# Out:
# name                bob
# age                  30
# city      san francisco
# salary              600
# Name: 1, dtype: object

# %%
df['age'].mean()
# Out:
# 25.0

# %%
df['salary'].max()
# Out:
# 700

# %%
print("The minimum salary is", df['salary'].min())
# Out:
# the minimum salary is 450

# %%
print(f"The minimum salary is {df['salary'].min()}. This is a high salary")
# Out:
# The minimum salary is 450. This is a high salary

# %%
df['salary'].mean()
# Out:
# 562.5

# %%
a=5
b=3

print(f"The linear system equation is : y = {a}x + {b}")
# Out:
# The linear system equation is : y = 5x + 3

# %%
ndata= [10 , 20, 30, 40 , 50]
s= pd.Series(ndata)
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
ndata= [10 , 20, 30, 40 , 50]
s= pd.Series(ndata)
s.min()
s.max()
s.mean()
# Out:
# 30.0

# %%
df.head()
# Out:
#       name  age           city  salary
# 0    alice   25       new york     500
# 1      bob   30  san francisco     600
# 2  charlie   17        chicago     450
# 3    david   28    los angeles     700

# %%
df.tail()
# Out:
#       name  age           city  salary
# 0    alice   25       new york     500
# 1      bob   30  san francisco     600
# 2  charlie   17        chicago     450
# 3    david   28    los angeles     700

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   age     4 non-null      int64
#  2   city    4 non-null      object
#  3   salary  4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
df.describe().T
# Out:
#         count   mean         std    min    25%    50%    75%    max
# age       4.0   25.0    5.715476   17.0   23.0   26.5   28.5   30.0
# salary    4.0  562.5  110.867789  450.0  487.5  550.0  625.0  700.0

# %%
merged_dg = pd.merge(df , df , on='name')
merged_dg
# Out:
#       name  age_x         city_x  salary_x  age_y         city_y  salary_y
# 0    alice     25       new york       500     25       new york       500
# 1      bob     30  san francisco       600     30  san francisco       600
# 2  charlie     17        chicago       450     17        chicago       450
# 3    david     28    los angeles       700     28    los angeles       700

# %%
df['new_salary'] = df['salary'].apply(lambda x: x+30)
df
# Out:
#       name  age           city  salary  new_salary
# 0    alice   25       new york     500         530
# 1      bob   30  san francisco     600         630
# 2  charlie   17        chicago     450         480
# 3    david   28    los angeles     700         730

# %%
sorted_df = df.sort_values(by='age')
sorted_df
# Out:
#       name  age           city  salary  new_salary
# 2  charlie   17        chicago     450         480
# 0    alice   25       new york     500         530
# 3    david   28    los angeles     700         730
# 1      bob   30  san francisco     600         630

# %%
df['is_adult']= df['age'].apply(lambda x: True if x>=18 else False)
df
# Out:
#       name  age           city  salary  new_salary  is_adult
# 0    alice   25       new york     500         530      True
# 1      bob   30  san francisco     600         630      True
# 2  charlie   17        chicago     450         480     False
# 3    david   28    los angeles     700         730      True

# %%
df1= pd.read_csv('diabetes.csv')
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df1= pd.read_csv('diabetes.csv')
df1.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df1= pd.read_csv('diabetes.csv')
df1.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %%
df1= pd.read_csv('diabetes.csv')
df1.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
df1= pd.read_csv('diabetes.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df1['Pregnancies'].unique()
# Out:
# array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15, 17, 12, 14])

# %%
correlation_matrix = df1.corr()
correlation_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
df1=df1.rename(columns={'diabetespedigreefunction':'DPF'})
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

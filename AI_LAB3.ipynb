# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmad777-Ai/Advanced-AI/blob/main/AI_LAB3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import datasets, model_selection
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error , mean_absolute_error

# %% [markdown]
# Step 1: load the data

# %%
df = pd.read_csv('Boston.csv')
df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox  ...  rad  tax  ptratio   black  lstat  medv
# 0           1  0.00632  18.0   2.31     0  0.538  ...    1  296     15.3  396.90   4.98  24.0
# 1           2  0.02731   0.0   7.07     0  0.469  ...    2  242     17.8  396.90   9.14  21.6
# 2           3  0.02729   0.0   7.07     0  0.469  ...    2  242     17.8  392.83   4.03  34.7
# 3           4  0.03237   0.0   2.18     0  0.458  ...    3  222     18.7  394.63   2.94  33.4
# 4           5  0.06905   0.0   2.18     0  0.458  ...    3  222     18.7  396.90   5.33  36.2
#
# [5 rows x 15 columns]

# %%
df= df.rename(columns={'medv':'TARGET' , 'rm':'RM' , 'lstat':'LSTAT'})
df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox  ...  rad  tax  ptratio   black  LSTAT  TARGET
# 0           1  0.00632  18.0   2.31     0  0.538  ...    1  296     15.3  396.90   4.98    24.0
# 1           2  0.02731   0.0   7.07     0  0.469  ...    2  242     17.8  396.90   9.14    21.6
# 2           3  0.02729   0.0   7.07     0  0.469  ...    2  242     17.8  392.83   4.03    34.7
# 3           4  0.03237   0.0   2.18     0  0.458  ...    3  222     18.7  394.63   2.94    33.4
# 4           5  0.06905   0.0   2.18     0  0.458  ...    3  222     18.7  396.90   5.33    36.2
#
# [5 rows x 15 columns]

# %%
df[["LSTAT" , "RM" , "TARGET"]]
# Out:
#      LSTAT     RM  TARGET
# 0     4.98  6.575    24.0
# 1     9.14  6.421    21.6
# 2     4.03  7.185    34.7
# 3     2.94  6.998    33.4
# 4     5.33  7.147    36.2
# ..     ...    ...     ...
# 501   9.67  6.593    22.4
# 502   9.08  6.120    20.6
# 503   5.64  6.976    23.9
# 504   6.48  6.794    22.0
# 505   7.88  6.030    11.9
#
# [506 rows x 3 columns]

# %%
# plt.figure(figsize=(10,5))

features = ["LSTAT" , "RM"]
target =df['TARGET']

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.scatter(df['LSTAT'], df['TARGET'])
plt.xlabel('LSTAT')
plt.ylabel('TARGET')
plt.grid(True)


plt.subplot(1, 2, 2)
plt.scatter(df['RM'], df['TARGET'])
plt.xlabel('RM')
plt.ylabel('TARGET')

plt.tight_layout()
plt.grid(True)
plt.show()

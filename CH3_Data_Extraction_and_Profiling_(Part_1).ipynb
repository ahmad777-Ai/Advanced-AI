# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmad777-Ai/Advanced-AI/blob/main/CH3_Data_Extraction_and_Profiling_(Part_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><img src="https://drive.google.com/uc?export=view&id=16HdIxB0tU-yjDTilrPF7BG71MyV2H3qQ" alt="PSUT"  width="180px">
# <p>
# Faculty of Information Technology
#  <br>
# Computer Science/AI <br>
# Data Analysis and Engineering  <br>
# CH3-Data Extraction and Profiling (Part 1)
# </p></center>

# %% [markdown]
# © Gaith Rjoub

# %%
#upload the DB
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-67ff6fd6-a1da-4ca3-b2c1-d510320cb1d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67ff6fd6-a1da-4ca3-b2c1-d510320cb1d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load an SQLite DB connection
import sqlite3

# %%
# Assign a connection to a variable named conn and point to the location of the database file
conn = sqlite3.connect('customer_sales (1).db')

# %%
conn

# %%
import pandas as pd

# Define query for tbl_customers
### "SELECT * FROM tbl_customers;"
query ="SELECT * FROM tbl_customers;"

# Run SQL query and store the results into a DataFrame
customersDF =pd.read_sql_query(query, conn)

customersDF
# Out:
#    Customer_ID First_Name Last_Name      Address_Line_1 Address_Line_2  \
# 0            1     Johnny     Smith     123 Main Street           None
# 1            2     Debbie    Winner   31 Roundtree Lane           None
# 2            3       Seth     Winer  310 Roundtree Lane           None
# 3            4    Anthony  Leedessa        Dallas Drive       Unit 806
# 4            5       Pete  Einstein       Morton Street           None
#
#            City State ZipCode         Phone                     Email
# 0         Miami    FL   12345  302-555-1212          jsmith@email.com
# 1         Dover    NJ   18888          None   debbie_winner@email.com
# 2         Dover    NJ   18888          None              sw@email.com
# 3       El Paso    TX   99928          None       alligator@email.com
# 4  Philadelphia    PA   28373  215-555-1212  peter_einstein@email.com

# %%
customersDF.shape
# Out:
# (5, 10)

# %%
customersDF.head(2)
# Out:
#    Customer_ID First_Name Last_Name     Address_Line_1 Address_Line_2   City  \
# 0            1     Johnny     Smith    123 Main Street           None  Miami
# 1            2     Debbie    Winner  31 Roundtree Lane           None  Dover
#
#   State ZipCode         Phone                    Email
# 0    FL   12345  302-555-1212         jsmith@email.com
# 1    NJ   18888          None  debbie_winner@email.com

# %%
customersDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer_ID     5 non-null      int64
#  1   First_Name      5 non-null      object
#  2   Last_Name       5 non-null      object
#  3   Address_Line_1  5 non-null      object
#  4   Address_Line_2  1 non-null      object
#  5   City            5 non-null      object
#  6   State           5 non-null      object
#  7   ZipCode         5 non-null      object
#  8   Phone           2 non-null      object
#  9   Email           5 non-null      object
# dtypes: int64(1), object(9)
# memory usage: 528.0+ bytes

# %%
customersDF['City'].describe()
# Out:
# count         5
# unique        4
# top       Dover
# freq          2
# Name: City, dtype: object

# %%
Q_tbl_sales ="SELECT * FROM tbl_sales;"

salesDF =pd.read_sql_query(Q_tbl_sales, conn)

salesDF
# Out:
#    Sale_ID   Sale_Date                Description  Customer_ID  Product_ID  \
# 0        1  12/31/2014       Purchased from Store            2           2
# 1        2   1/15/2015             Phone Purchase            1           1
# 2        3   6/14/2015          Internet Purchase            3           3
# 3        4  11/11/2015  Sales Convention Purchase            3           3
# 4        5   4/18/2016          Internet Purchase            4           1
# 5        6  10/15/2016       Purchased from Store            5           1
# 6        7   3/17/2017          Internet Purchase            4           1
# 7        8   6/15/2018       Purchased from Store            3           3
# 8        9   5/25/2019          Internet Purchase            1           3
# 9       10    6/9/2019          Internet Purchase            2           3
#
#    Sales_Amount  Sales_Quantity
# 0            20               1
# 1            30               2
# 2             5               1
# ...

# %%
salesDF.shape
# Out:
# (10, 7)

# %%
salesDF.head(3)
# Out:
#    Sale_ID   Sale_Date           Description  Customer_ID  Product_ID  \
# 0        1  12/31/2014  Purchased from Store            2           2
# 1        2   1/15/2015        Phone Purchase            1           1
# 2        3   6/14/2015     Internet Purchase            3           3
#
#    Sales_Amount  Sales_Quantity
# 0            20               1
# 1            30               2
# 2             5               1

# %%
salesDF.sort_values(by='Sales_Amount',ascending=False)
# Out:
#    Sale_ID   Sale_Date                Description  Customer_ID  Product_ID  \
# 3        4  11/11/2015  Sales Convention Purchase            3           3
# 1        2   1/15/2015             Phone Purchase            1           1
# 0        1  12/31/2014       Purchased from Store            2           2
# 4        5   4/18/2016          Internet Purchase            4           1
# 5        6  10/15/2016       Purchased from Store            5           1
# 6        7   3/17/2017          Internet Purchase            4           1
# 8        9   5/25/2019          Internet Purchase            1           3
# 9       10    6/9/2019          Internet Purchase            2           3
# 2        3   6/14/2015          Internet Purchase            3           3
# 7        8   6/15/2018       Purchased from Store            3           3
#
#    Sales_Amount  Sales_Quantity
# 3           500             100
# 1            30               2
# 0            20               1
# ...

# %%
Q_Cond_sales ="SELECT * FROM tbl_sales WHERE Sales_Amount>=20 ;"

salesCondDF =pd.read_sql_query(Q_Cond_sales, conn)

salesCondDF
# Out:
#    Sale_ID   Sale_Date                Description  Customer_ID  Product_ID  \
# 0        1  12/31/2014       Purchased from Store            2           2
# 1        2   1/15/2015             Phone Purchase            1           1
# 2        4  11/11/2015  Sales Convention Purchase            3           3
# 3        5   4/18/2016          Internet Purchase            4           1
# 4        6  10/15/2016       Purchased from Store            5           1
# 5        7   3/17/2017          Internet Purchase            4           1
#
#    Sales_Amount  Sales_Quantity
# 0            20               1
# 1            30               2
# 2           500             100
# 3            20               2
# 4            20               1
# 5            20               1

# %%
mask1 = salesDF['Sales_Amount']>=20

# %%
salesDF[mask1]
# Out:
#    Sale_ID   Sale_Date                Description  Customer_ID  Product_ID  \
# 0        1  12/31/2014       Purchased from Store            2           2
# 1        2   1/15/2015             Phone Purchase            1           1
# 3        4  11/11/2015  Sales Convention Purchase            3           3
# 4        5   4/18/2016          Internet Purchase            4           1
# 5        6  10/15/2016       Purchased from Store            5           1
# 6        7   3/17/2017          Internet Purchase            4           1
#
#    Sales_Amount  Sales_Quantity
# 0            20               1
# 1            30               2
# 3           500             100
# 4            20               2
# 5            20               1
# 6            20               1

# %%
Q_Cond2_sales ="SELECT AVG(Sales_Amount) FROM tbl_sales;"

salesCond2DF =pd.read_sql_query(Q_Cond2_sales, conn)

salesCond2DF
# Out:
#    AVG(Sales_Amount)
# 0               64.0

# %%
salesDF['Sales_Amount'].mean()
# Out:
# 64.0

# %%
Q_Cond3_sales ="SELECT AVG(Sales_Amount) FROM tbl_sales WHERE Product_ID==1;"

salesCond3DF =pd.read_sql_query(Q_Cond3_sales, conn)

salesCond3DF
# Out:
#    AVG(Sales_Amount)
# 0               22.5

# %%
mask2 = salesDF['Product_ID']==1

# %%
salesDF[mask2]['Sales_Amount'].mean()
# Out:
# 22.5

# %%
Q_Cond4_sales ="SELECT count(Sale_ID) FROM tbl_sales WHERE Sales_Amount>=20 ;"

salesCond4DF =pd.read_sql_query(Q_Cond4_sales, conn)

salesCond4DF
# Out:
#    count(Sale_ID)
# 0               6

# %%
mask3 = salesDF['Sales_Amount']>=20

mask3
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# Name: Sales_Amount, dtype: bool

# %%
salesDF[mask3].shape[0]
# Out:
# 6

# %%
len(salesDF[mask3])
# Out:
# 6
